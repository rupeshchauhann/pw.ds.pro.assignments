# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('/Users/rupeshchauhan/Downloads/heart_failure_clinical_records_dataset.csv')

# %%
# Display the first few rows of the dataset
print(df.head())
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %% [markdown]
# #### 1

# %%
# Summary statistics of numeric features
print(df.describe())
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %% [markdown]
# #### 2

# %%
# Distribution of Age Among Heart Failure Patients
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='age', bins=20, kde=True)
plt.title('Distribution of Age Among Heart Failure Patients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### 3

# %%
# Death Rate Variation with Age
death_rate_age = df.groupby(pd.cut(df['age'], bins=10)).mean()['DEATH_EVENT']
plt.figure(figsize=(8, 6))
death_rate_age.plot(kind='bar')
plt.title('Death Rate Variation with Age')
plt.xlabel('Age Group')
plt.ylabel('Death Rate')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/j7/554c95g910dbn6cwq06qd0wc0000gn/T/ipykernel_1559/1277979437.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   death_rate_age = df.groupby(pd.cut(df['age'], bins=10)).mean()['DEATH_EVENT']

# %% [markdown]
# #### 4

# %%
# Percentage of Male and Female Patients
gender_percentage = df['sex'].value_counts(normalize=True) * 100
print("Percentage of Male Patients:", gender_percentage[1])
print("Percentage of Female Patients:", gender_percentage[0])
# Out:
# Percentage of Male Patients: 64.88294314381271
# Percentage of Female Patients: 35.11705685618729

# %% [markdown]
# #### 5

# %%
# Platelet Count Variation Among Different Age Groups
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x=pd.cut(df['age'], bins=5), y='platelets')
plt.title('Platelet Count Variation Among Different Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Platelet Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### 6

# %%
# Correlation Between Creatinine and Sodium Levels
correlation = df['serum_creatinine'].corr(df['serum_sodium'])
print("Correlation between Creatinine and Sodium levels:", correlation)
# Out:
# Correlation between Creatinine and Sodium levels: -0.18909521009117392

# %% [markdown]
# #### 7

# %%
# Prevalence of High Blood Pressure Between Genders
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='high_blood_pressure', hue='sex')
plt.title('Prevalence of High Blood Pressure Between Genders')
plt.xlabel('High Blood Pressure')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 8

# %%
# Relationship Between Smoking Habits and Heart Failure Occurrence
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='smoking', hue='DEATH_EVENT')
plt.title('Relationship Between Smoking Habits and Heart Failure Occurrence')
plt.xlabel('Smoking')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 9

# %%
# Patterns in Distribution of Death Events Across Age Groups
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='age', hue='DEATH_EVENT', multiple='stack', bins=20, kde=True)
plt.title('Distribution of Death Events Across Age Groups')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### 10

# %%
# Difference in Ejection Fraction Between Patients with and without Diabetes
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='diabetes', y='ejection_fraction')
plt.title('Difference in Ejection Fraction Between Patients with and without Diabetes')
plt.xlabel('Diabetes')
plt.ylabel('Mean Ejection Fraction')
plt.show()

# %% [markdown]
# #### 11

# %%
# Variation in Serum Creatinine Levels Between Survived and Deceased Patients
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='DEATH_EVENT', y='serum_creatinine')
plt.title('Variation in Serum Creatinine Levels Between Survived and Deceased Patients')
plt.xlabel('Death Event')
plt.ylabel('Serum Creatinine')
plt.xticks([0, 1], ['survived', 'deceased'])
plt.show()
